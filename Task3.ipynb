# %% [markdown]
# <a href="https://colab.research.google.com/github/koteshvarma2/Data_Science/blob/main/Task3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

data = [12, 15, 14, 10, 18, 20, 13, 16, 12, 19]

variance = np.var(data, ddof=1)
std_dev = np.std(data, ddof=1)

print(f"Variance: {variance}")
print(f"Standard Deviation: {std_dev}")

series = pd.Series(data)
summary = series.describe()
print("\nSummary statistics:\n", summary)

plt.hist(data, bins=5, edgecolor='black')
plt.title("Data Distribution")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.show()

t_stat, p_val = stats.ttest_1samp(data, 15)
print(f"\nT-test statistic: {t_stat:.3f}, p-value: {p_val:.3f}")
# Out:
# Variance: 10.988888888888889
# Standard Deviation: 3.314949304120485
#
# Summary statistics:
#  count    10.000000
# mean     14.900000
# std       3.314949
# min      10.000000
# 25%      12.250000
# 50%      14.500000
# 75%      17.500000
# max      20.000000
# dtype: float64
# T-test statistic: -0.095, p-value: 0.926
